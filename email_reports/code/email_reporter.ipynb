# %%
#note: may not work because of  differences in browsers layout or screen proportion
#(in my device) {opera browser 67% zoom & screen 1280x960}

import time
import pyautogui
import pyperclip
import pandas as pd

pyautogui.FAILSAFE = True

pyautogui.PAUSE = 1

pyautogui.press("win")
time.sleep(1)
pyautogui.write("opera")
time.sleep(1)
pyautogui.press("enter")
time.sleep(2)

pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://drive.google.com/drive/folders/1-zdmbi33idP6g-UtNMHFcLboh4N9CHa3")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(2)

pyautogui.click(x=463, y=416, clicks=2)
time.sleep(2)
pyautogui.click(x=463, y=416)
time.sleep(2)
pyautogui.click(x=1651, y=258)
time.sleep(2)
pyautogui.click(x=1350, y=793)
time.sleep(5)


df = pd.read_excel(r"../datasets/feb_sells.xlsx")
#display(tabela)
billing = df["Valor Final"].sum()
amount = df["Quantidade"].sum()

pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://mail.google.com/mail/u/0/#inbox")
pyautogui.hotkey("ctrl","v")
pyautogui.press("enter")
time.sleep(2)

pyautogui.click(x=139, y=265)
pyautogui.write("nicolasleite2003@gmail.com")
pyautogui.press("tab")
pyautogui.press("tab")
pyperclip.copy("Sells Report")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("tab")

text = f'''
Good morning,
Biliing R${billing:,}
Amount of products: {amount:,}
See ya'''
pyperclip.copy(text)
pyautogui.hotkey("ctrl", "v")
time.sleep(1)
pyautogui.hotkey("ctrl","enter")

time.sleep(3)
pyautogui.hotkey("ctrl", "w")
pyautogui.hotkey("ctrl", "w")
# Out:
# Point(x=565, y=317)
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
# ...
