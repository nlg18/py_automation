# %%
# ANTES DE EXECUTAR:


#1 NAVEGADOR OPERA:
#    ZOOM DO YYOUTUBE: 67%
#    ADBLOCK LIGADO (PARA EVITAR QUE APAREÇA ANÚNCIO
#        NO PRIMEIRO RESULTADO DA PESQUISA DO YOUTUBE)


#2 VERIFICAR SE A PLAYLIST DO YOUTUBE ESTÁ:
#    EM SEGUNDO (ABAIXO DE WATCH LATER) 
#        (basta criar e add um vídeo, antes de executar o código)
#    LINK DA PLAYLIST:
link_playlist = "https://www.youtube.com/playlist?list=PL4Zjpi-MjA75IJMjMekHFL-S1pOBNPzoo"



#3 colar setlist no SETLIST.txt:
#    cru (apenas o nome da música)
#    uma música por linha


####################################################

import time
import pyautogui
import pyperclip

pyautogui.FAILSAFE = True
# stop running if mouse(x=0, y=0)


time.sleep(1)
pyautogui.press("win")
time.sleep(1)
pyautogui.click(x=138, y=325)
time.sleep(4)

pyautogui.press("enter")
time.sleep(2)

pyautogui.click(x=665, y=53)
time.sleep(1)
pyautogui.click(x=47, y=135)
time.sleep(1)
pyautogui.click(x=189, y=236)
time.sleep(1)
pyautogui.click(x=541, y=302)
time.sleep(3)

pyperclip.copy(r"../datasets/SETLIST.txt")
pyautogui.hotkey("ctrl","v")
time.sleep(2)
pyautogui.press("enter")
time.sleep(4)

pyautogui.press("tab")
time.sleep(1)
pyautogui.press("tab")
time.sleep(1)
pyautogui.press("enter")
time.sleep(3)



pyautogui.hotkey("ctrl","b")
time.sleep(2)
pyautogui.press("enter")
time.sleep(2)
pyautogui.press("left")
time.sleep(1)
pyautogui.press("enter")
time.sleep(3)


pyautogui.press("win")
time.sleep(1)
pyperclip.copy("opera")
time.sleep(1)
pyautogui.hotkey("ctrl","v")
time.sleep(1)
pyautogui.press("enter")
time.sleep(1)

pyautogui.hotkey("ctrl", "t")

pyperclip.copy("https://www.youtube.com")
time.sleep(1)
pyautogui.hotkey("ctrl","v")
time.sleep(1)
pyautogui.press("enter")
time.sleep(3)

pyautogui.click(x=771, y=181)



import pandas as pd

x = pd.read_excel(r"../datasets/Pasta1.xlsx")
# Converter todas as colunas em uma lista
lista_colunas = x.values.tolist()



#INICIO DO LOOP
for i in range(len(lista_colunas)):
    
    pyautogui.click(x=771, y=181, clicks=3)
    
    pyautogui.press("del")
    
    pyperclip.copy(str(lista_colunas[i]))
    pyautogui.hotkey("ctrl","v")
    time.sleep(1)
 
    pyperclip.copy(" guitar backing track")
    pyautogui.hotkey("ctrl","v")
    time.sleep(1)
    
    pyautogui.press("enter")
 
    time.sleep(2)
    pyautogui.click(x=1808, y=334)
    time.sleep(1)
    pyautogui.click(x=1679, y=489)
    time.sleep(1)
    pyautogui.click(x=910, y=477)
    time.sleep(3)
    
    pyautogui.click(x=771, y=181, clicks=1)
    time.sleep(1)
    



#link da playlist
pyperclip.copy(link_playlist)
pyautogui.click(x=710, y=100)
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(4)
pyautogui.click(x=484, y=811)
time.sleep(1)
pyautogui.hotkey("shift", "n")


#pyautogui.hotkey("ctrl","w")
